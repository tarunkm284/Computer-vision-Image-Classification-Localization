# %%
# !pip install xmltodict
# Out:
# Requirement already satisfied: xmltodict in c:\users\hp\anaconda3\lib\site-packages (0.13.0)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob
import PIL
import cv2
import xmltodict
import random
from tqdm import tqdm
from PIL import ImageDraw
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, MaxPool2D, LeakyReLU, Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import backend as K
from tensorflow.keras.utils import plot_model

# %%
path = "training_images"

# %%
def normalize(path):
    images=[]
    names =[]
    for file in tqdm(glob.glob(path +"/*.jpg")):
        image = cv2.resize(cv2.imread(file), (228,228))
        image = np.array(image)
        name = file.split('/')[-1].split('_')[0]
        images.append(image)
        names.append(name)
    return images,names

# %%
images,names = normalize(path)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 186/186 [00:01<00:00, 120.73it/s]

# %%
fig = plt.figure(figsize=(20,15))

for i in range(9):
    r = random.randint(1,186)
    plt.subplot(3,3,i+1)
    plt.imshow(images[r])
    plt.xlabel(names[r])
    
plt.show()

# %%
def get_bbox(xml_path):
    bboxes =[]
    classnames=[]
    for file in tqdm(glob.glob(xml_path + "/*.xml")):
        x = xmltodict.parse(open(file, 'rb'))
        bbox = x['annotation']['object']['bndbox']
        name = x['annotation']['object']['name']
        bbox = np.array([int(bbox['xmin']),int(bbox['ymin']),int(bbox['xmax']),int(bbox['ymax'])])
        bbox2 = [None]*4
        bbox2[0] = bbox[0]
        bbox2[1] = bbox[1]
        bbox2[2] = bbox[2]
        bbox2[3] = bbox[3]
        bbox2 = np.array(bbox2)/228
        bboxes.append(bbox2)
        classnames.append(name)
    return np.array(bboxes), classnames

# %%
bboxes, classnames = get_bbox(path)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 186/186 [00:00<00:00, 475.74it/s]

# %%
encoder = LabelBinarizer()
classnames = encoder.fit_transform(classnames)
Y = np.concatenate([bboxes, classnames], axis=1)
X = np.array(images)

# %%
import pickle
seri = pickle.dumps(encoder)

# %%
with open('file.pkl', 'wb') as file:
    # A new file will be created
    pickle.dump(encoder, file)

# %%
# with open(os.path.join(encoder,'labels'), 'wb') as f:
#     pickle.dump(lb, f)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.1)

# %%
def calculate_iou(target, pred):
    
    xA = K.maximum(target[:,0], pred[:,0])
    yA = K.maximum(target[:,1], pred[:,1])
    xB = K.minimum(target[:,2], pred[:,2])
    yB = K.minimum(target[:,3], pred[:,3])
    interArea = K.maximum(0.0, xB-xA)*K.maximum(0.0,yB-yA)
    boxAarea = (target[:,2]-target[:,0])*(target[:,3]-target[:,1])
    boxBarea = (pred[:,2]-pred[:,0]) * (pred[:,3]-pred[:,1])
    
    iou = interArea / (boxAarea+boxBarea - interArea)
    return iou


def custom_loss(y_true, y_pred):
    mse = tf.losses.mean_squared_error(y_true, y_pred)
    iou = calculate_iou(y_true , y_pred)
    return mse + (1-iou)

def iou_metric(y_true, y_pred):
    return calculate_iou(y_true, y_pred)

# %%
input_shape = ( 228 , 228 , 3 )
dropout_rate = 0.5
classes =3
alpha = 0.2
prediction_units = 4+ classes

# %%
def block1(filters,X):
    
    x = Conv2D(filters, kernel_size=(3,3), strides=1 )(X)
    x = LeakyReLU(alpha)(x)
    x = Conv2D(filters, (3,3), strides=1)(x)
    x = LeakyReLU(alpha)(x)
    x = MaxPool2D((2,2))(x)
    return x

def block2(units,X):
    
    x = Dense(units)(X)
    x = LeakyReLU(alpha)(x)    
    return x

# %%
def mymodel():
    
    model_input = Input(shape=(228,228,3))
    x= block1(16, model_input)
    x= block1(32,x)
    x = block1(64,x)
    x= block1(128,x)
    x = block1(256,x)
    
    x = Flatten()(x)
    x = block2(1240, x)
    x = block2(640, x)
    x = block2(480,x)
    x = block2(120,x)
    x = block2(62,x)
    model_outputs = Dense(prediction_units)(x)
    
    model = Model(inputs=[model_input], outputs=[model_outputs])
    
    model.compile( tf.keras.optimizers.Adam(0.0001),
                 loss=custom_loss,
                 metrics=[iou_metric])

#     model.compile( tf.keras.optimizers.Adam(0.0001),loss="mean_squared_error",
#                  metrics=[iou_metric])
    
    return model

# %%
model = mymodel()
#model.summary()

# %%
plot_model(model,to_file='model.png',show_shapes=True,show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

filepath = 'model-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
history = model.fit( 
    X_train ,
    Y_train , 
    validation_data=( X_test , Y_test ),
    epochs=100 ,
    batch_size=3
)
# Out:
# Epoch 1/100
# 56/56 [==============================] - 5s 96ms/step - loss: 0.5299 - iou_metric: 0.5479 - val_loss: 0.5122 - val_iou_metric: 0.5654
# Epoch 2/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.5424 - iou_metric: 0.5366 - val_loss: 0.7148 - val_iou_metric: 0.3972
# Epoch 3/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.6245 - iou_metric: 0.4651 - val_loss: 0.5701 - val_iou_metric: 0.5047
# Epoch 4/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.5062 - iou_metric: 0.5585 - val_loss: 0.5834 - val_iou_metric: 0.4891
# Epoch 5/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.5437 - iou_metric: 0.5319 - val_loss: 0.6102 - val_iou_metric: 0.4641
# Epoch 6/100
# 56/56 [==============================] - 5s 83ms/step - loss: 0.4879 - iou_metric: 0.5704 - val_loss: 0.5788 - val_iou_metric: 0.4857
# Epoch 7/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.4469 - iou_metric: 0.6041 - val_loss: 0.4627 - val_iou_metric: 0.5934
# Epoch 8/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.4393 - iou_metric: 0.6091 - val_loss: 0.4642 - val_iou_metric: 0.5944
# Epoch 9/100
# 56/56 [==============================] - 4s 79ms/step - loss: 0.4610 - iou_metric: 0.5869 - val_loss: 0.5192 - val_iou_metric: 0.5311
# Epoch 10/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.4348 - iou_metric: 0.6103 - val_loss: 0.4850 - val_iou_metric: 0.5628
# Epoch 11/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.4444 - iou_metric: 0.5928 - val_loss: 0.4633 - val_iou_metric: 0.5839
# Epoch 12/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.3911 - iou_metric: 0.6414 - val_loss: 0.5064 - val_iou_metric: 0.5366
# Epoch 13/100
# 56/56 [==============================] - 5s 80ms/step - loss: 0.4080 - iou_metric: 0.6250 - val_loss: 0.4346 - val_iou_metric: 0.6056
# Epoch 14/100
# 56/56 [==============================] - 5s 83ms/step - loss: 0.3699 - iou_metric: 0.6562 - val_loss: 0.4693 - val_iou_metric: 0.5780
# Epoch 15/100
# 56/56 [==============================] - 5s 83ms/step - loss: 0.3873 - iou_metric: 0.6406 - val_loss: 0.4742 - val_iou_metric: 0.5721
# Epoch 16/100
# 56/56 [==============================] - 5s 80ms/step - loss: 0.3909 - iou_metric: 0.6360 - val_loss: 0.5293 - val_iou_metric: 0.5164
# Epoch 17/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.3696 - iou_metric: 0.6555 - val_loss: 0.4513 - val_iou_metric: 0.5962
# Epoch 18/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.3575 - iou_metric: 0.6633 - val_loss: 0.4101 - val_iou_metric: 0.6346
# Epoch 19/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.3511 - iou_metric: 0.6708 - val_loss: 0.4480 - val_iou_metric: 0.5944
# Epoch 20/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.3313 - iou_metric: 0.6942 - val_loss: 0.4188 - val_iou_metric: 0.6193
# Epoch 21/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.3247 - iou_metric: 0.6956 - val_loss: 0.4389 - val_iou_metric: 0.5966
# Epoch 22/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.3707 - iou_metric: 0.6592 - val_loss: 0.4304 - val_iou_metric: 0.6089
# Epoch 23/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.2942 - iou_metric: 0.7246 - val_loss: 0.4008 - val_iou_metric: 0.6349
# Epoch 24/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.3185 - iou_metric: 0.7003 - val_loss: 0.4507 - val_iou_metric: 0.5854
# Epoch 25/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.2738 - iou_metric: 0.7411 - val_loss: 0.5943 - val_iou_metric: 0.4546
# Epoch 26/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.2999 - iou_metric: 0.7182 - val_loss: 0.4588 - val_iou_metric: 0.5764
# Epoch 27/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.3031 - iou_metric: 0.7144 - val_loss: 0.4234 - val_iou_metric: 0.6277
# Epoch 28/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.3389 - iou_metric: 0.6854 - val_loss: 0.4770 - val_iou_metric: 0.5700
# Epoch 29/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.3371 - iou_metric: 0.6825 - val_loss: 0.4029 - val_iou_metric: 0.6364
# Epoch 30/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.2762 - iou_metric: 0.7399 - val_loss: 0.3755 - val_iou_metric: 0.6587
# Epoch 31/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.2694 - iou_metric: 0.7459 - val_loss: 0.4114 - val_iou_metric: 0.6286
# Epoch 32/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.2751 - iou_metric: 0.7369 - val_loss: 0.4348 - val_iou_metric: 0.5960
# Epoch 33/100
# 56/56 [==============================] - 4s 79ms/step - loss: 0.2581 - iou_metric: 0.7548 - val_loss: 0.3630 - val_iou_metric: 0.6675
# Epoch 34/100
# 56/56 [==============================] - 4s 79ms/step - loss: 0.2673 - iou_metric: 0.7501 - val_loss: 0.3849 - val_iou_metric: 0.6461
# Epoch 35/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.2492 - iou_metric: 0.7637 - val_loss: 0.4042 - val_iou_metric: 0.6328
# Epoch 36/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.2566 - iou_metric: 0.7564 - val_loss: 0.4228 - val_iou_metric: 0.6083
# Epoch 37/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.2762 - iou_metric: 0.7376 - val_loss: 0.4310 - val_iou_metric: 0.6038
# Epoch 38/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.2584 - iou_metric: 0.7525 - val_loss: 0.4195 - val_iou_metric: 0.6136
# Epoch 39/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.2671 - iou_metric: 0.7447 - val_loss: 0.3681 - val_iou_metric: 0.6614
# Epoch 40/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.2212 - iou_metric: 0.7890 - val_loss: 0.3674 - val_iou_metric: 0.6597
# Epoch 41/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.2252 - iou_metric: 0.7845 - val_loss: 0.3916 - val_iou_metric: 0.6400
# Epoch 42/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.2405 - iou_metric: 0.7720 - val_loss: 0.3934 - val_iou_metric: 0.6391
# Epoch 43/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.2285 - iou_metric: 0.7816 - val_loss: 0.3978 - val_iou_metric: 0.6292
# Epoch 44/100
# 56/56 [==============================] - 4s 78ms/step - loss: 0.2351 - iou_metric: 0.7746 - val_loss: 0.4337 - val_iou_metric: 0.6001
# Epoch 45/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.2244 - iou_metric: 0.7851 - val_loss: 0.3645 - val_iou_metric: 0.6639
# Epoch 46/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.2187 - iou_metric: 0.7889 - val_loss: 0.3795 - val_iou_metric: 0.6455
# Epoch 47/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.2394 - iou_metric: 0.7696 - val_loss: 0.3684 - val_iou_metric: 0.6629
# Epoch 48/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1978 - iou_metric: 0.8091 - val_loss: 0.3473 - val_iou_metric: 0.6828
# Epoch 49/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.2054 - iou_metric: 0.8028 - val_loss: 0.3771 - val_iou_metric: 0.6515
# Epoch 50/100
# 56/56 [==============================] - 5s 83ms/step - loss: 0.1950 - iou_metric: 0.8141 - val_loss: 0.3725 - val_iou_metric: 0.6585
# Epoch 51/100
# 56/56 [==============================] - 5s 83ms/step - loss: 0.1958 - iou_metric: 0.8123 - val_loss: 0.3704 - val_iou_metric: 0.6563
# Epoch 52/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.1875 - iou_metric: 0.8205 - val_loss: 0.3633 - val_iou_metric: 0.6640
# Epoch 53/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.1886 - iou_metric: 0.8188 - val_loss: 0.3772 - val_iou_metric: 0.6513
# Epoch 54/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1902 - iou_metric: 0.8190 - val_loss: 0.3572 - val_iou_metric: 0.6676
# Epoch 55/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.2007 - iou_metric: 0.8062 - val_loss: 0.3640 - val_iou_metric: 0.6583
# Epoch 56/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1867 - iou_metric: 0.8223 - val_loss: 0.3733 - val_iou_metric: 0.6523
# Epoch 57/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1804 - iou_metric: 0.8266 - val_loss: 0.3402 - val_iou_metric: 0.6840
# Epoch 58/100
# 56/56 [==============================] - 5s 85ms/step - loss: 0.1804 - iou_metric: 0.8268 - val_loss: 0.3409 - val_iou_metric: 0.6851
# Epoch 59/100
# 56/56 [==============================] - 5s 86ms/step - loss: 0.1756 - iou_metric: 0.8318 - val_loss: 0.3473 - val_iou_metric: 0.6775
# Epoch 60/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.1834 - iou_metric: 0.8233 - val_loss: 0.3268 - val_iou_metric: 0.6972
# Epoch 61/100
# 56/56 [==============================] - 5s 83ms/step - loss: 0.1747 - iou_metric: 0.8323 - val_loss: 0.3458 - val_iou_metric: 0.6809
# Epoch 62/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.1634 - iou_metric: 0.8428 - val_loss: 0.3556 - val_iou_metric: 0.6720
# Epoch 63/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.1864 - iou_metric: 0.8200 - val_loss: 0.3362 - val_iou_metric: 0.6895
# Epoch 64/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1683 - iou_metric: 0.8371 - val_loss: 0.3465 - val_iou_metric: 0.6775
# Epoch 65/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1762 - iou_metric: 0.8298 - val_loss: 0.3686 - val_iou_metric: 0.6556
# Epoch 66/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.1832 - iou_metric: 0.8241 - val_loss: 0.3289 - val_iou_metric: 0.6968
# Epoch 67/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.1825 - iou_metric: 0.8242 - val_loss: 0.3362 - val_iou_metric: 0.6903
# Epoch 68/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1611 - iou_metric: 0.8441 - val_loss: 0.3399 - val_iou_metric: 0.6869
# Epoch 69/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1690 - iou_metric: 0.8361 - val_loss: 0.3369 - val_iou_metric: 0.6918
# Epoch 70/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.1598 - iou_metric: 0.8458 - val_loss: 0.3158 - val_iou_metric: 0.7075
# Epoch 71/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.1657 - iou_metric: 0.8409 - val_loss: 0.3462 - val_iou_metric: 0.6752
# Epoch 72/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1666 - iou_metric: 0.8392 - val_loss: 0.3502 - val_iou_metric: 0.6782
# Epoch 73/100
# 56/56 [==============================] - 5s 83ms/step - loss: 0.1659 - iou_metric: 0.8420 - val_loss: 0.3904 - val_iou_metric: 0.6449
# Epoch 74/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.1783 - iou_metric: 0.8274 - val_loss: 0.3408 - val_iou_metric: 0.6799
# Epoch 75/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1769 - iou_metric: 0.8306 - val_loss: 0.3798 - val_iou_metric: 0.6494
# Epoch 76/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1626 - iou_metric: 0.8429 - val_loss: 0.3334 - val_iou_metric: 0.6896
# Epoch 77/100
# 56/56 [==============================] - 5s 87ms/step - loss: 0.1711 - iou_metric: 0.8344 - val_loss: 0.3466 - val_iou_metric: 0.6793
# Epoch 78/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1675 - iou_metric: 0.8380 - val_loss: 0.3526 - val_iou_metric: 0.6768
# Epoch 79/100
# 56/56 [==============================] - 5s 80ms/step - loss: 0.1510 - iou_metric: 0.8538 - val_loss: 0.3402 - val_iou_metric: 0.6847
# Epoch 80/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1420 - iou_metric: 0.8626 - val_loss: 0.3364 - val_iou_metric: 0.6877
# Epoch 81/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1524 - iou_metric: 0.8538 - val_loss: 0.3300 - val_iou_metric: 0.6928
# Epoch 82/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1538 - iou_metric: 0.8509 - val_loss: 0.3274 - val_iou_metric: 0.6935
# Epoch 83/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.1637 - iou_metric: 0.8412 - val_loss: 0.3358 - val_iou_metric: 0.6910
# Epoch 84/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1511 - iou_metric: 0.8541 - val_loss: 0.3141 - val_iou_metric: 0.7072
# Epoch 85/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1578 - iou_metric: 0.8468 - val_loss: 0.3494 - val_iou_metric: 0.6771
# Epoch 86/100
# 56/56 [==============================] - 5s 80ms/step - loss: 0.1297 - iou_metric: 0.8748 - val_loss: 0.3353 - val_iou_metric: 0.6888
# Epoch 87/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1331 - iou_metric: 0.8714 - val_loss: 0.3369 - val_iou_metric: 0.6854
# Epoch 88/100
# 56/56 [==============================] - 5s 84ms/step - loss: 0.1252 - iou_metric: 0.8788 - val_loss: 0.3373 - val_iou_metric: 0.6858
# Epoch 89/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1452 - iou_metric: 0.8591 - val_loss: 0.3345 - val_iou_metric: 0.6861
# Epoch 90/100
# 56/56 [==============================] - 5s 83ms/step - loss: 0.1371 - iou_metric: 0.8673 - val_loss: 0.3452 - val_iou_metric: 0.6777
# Epoch 91/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1344 - iou_metric: 0.8717 - val_loss: 0.3413 - val_iou_metric: 0.6863
# Epoch 92/100
# 56/56 [==============================] - 4s 80ms/step - loss: 0.1426 - iou_metric: 0.8614 - val_loss: 0.3584 - val_iou_metric: 0.6766
# Epoch 93/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1426 - iou_metric: 0.8619 - val_loss: 0.3397 - val_iou_metric: 0.6846
# Epoch 94/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1397 - iou_metric: 0.8643 - val_loss: 0.3407 - val_iou_metric: 0.6825
# Epoch 95/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1351 - iou_metric: 0.8691 - val_loss: 0.3417 - val_iou_metric: 0.6770
# Epoch 96/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1415 - iou_metric: 0.8624 - val_loss: 0.3529 - val_iou_metric: 0.6743
# Epoch 97/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1465 - iou_metric: 0.8583 - val_loss: 0.3375 - val_iou_metric: 0.6859
# Epoch 98/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1368 - iou_metric: 0.8673 - val_loss: 0.3443 - val_iou_metric: 0.6856
# Epoch 99/100
# 56/56 [==============================] - 5s 82ms/step - loss: 0.1402 - iou_metric: 0.8647 - val_loss: 0.3518 - val_iou_metric: 0.6717
# Epoch 100/100
# 56/56 [==============================] - 5s 81ms/step - loss: 0.1259 - iou_metric: 0.8776 - val_loss: 0.3392 - val_iou_metric: 0.6845

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

acc = history.history['iou_metric']
val_acc = history.history['val_iou_metric']


plt.figure(figsize=(10,15))
plt.subplot(2,1,1)
plt.plot(loss , linewidth=3 ,label='train loss')
plt.plot(val_loss , linewidth=3, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss / val_loss')
plt.legend()

# %%
plt.subplot(2,1,2)
plt.plot(acc , linewidth=3 ,label='train acc')
plt.plot(val_acc , linewidth=3, label='val acc')
plt.xlabel('epochs')
plt.ylabel('Accuracy / Val_Accuracy')
plt.legend()

# %%
def drawbox(model,image, y_true, le):
    img = tf.cast(np.expand_dims(image, axis=0), tf.float32)
    y_true = np.expand_dims(y_true, axis=0)
    
    #prediction
    predict = model.predict(img)
    
    #Box coordinates
    Y_test_box =y_true[...,0:4]*228
    pred_box = predict[...,0:4]*228
    
    x = pred_box[0][0]
    y = pred_box[0][1]
    w = pred_box[0][2]
    h = pred_box[0][3]
    #get class name
    trans= le.inverse_transform(predict[...,4:])
    
    im = PIL.Image.fromarray(image)
    draw=ImageDraw.Draw(im)
    draw.rectangle([x,y,w,h], outline='red')
    plt.xlabel(trans[0])
    plt.imshow(im)
    
    iou = calculate_iou(Y_test_box, pred_box)

# %%
fig = plt.figure(figsize=(20,15))

for i in range(9):
    r = random.randint(1,10)
    plt.subplot(3,3,i+1)
    drawbox(model,X_test[r], Y_test[r], encoder)    
plt.show()
# Out:
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
import tensorflow as tf

# %%
model.save("image_localization_model.h5")

# %%
rmodel = tf.keras.models.load_model("image_localization_model.h5", compile=False)

# %%
import matplotlib.pyplot as plt

# %%
image = cv2.resize(cv2.imread(path+"/cucumber_2.jpg"), (228,228))
predictimg = np.array(image)

# %%
plt.imshow(predictimg)

# %%
def predictDrawbox(model,image, le):
    img = tf.cast(np.expand_dims(image, axis=0), tf.float32)
    
    #prediction
    predict = model.predict(img)
    
    pred_box = predict[...,0:4]*228
    
    x = pred_box[0][0]
    y = pred_box[0][1]
    w = pred_box[0][2]
    h = pred_box[0][3]
    #get class name
    trans= le.inverse_transform(predict[...,4:])
    
    im = PIL.Image.fromarray(image)
    draw=ImageDraw.Draw(im)
    draw.rectangle([x,y,w,h], outline='red')
    plt.xlabel(trans[0])
    plt.imshow(im)

# %%
predictDrawbox(rmodel,predictimg,encoder)
# Out:
# 1/1 [==============================] - 0s 202ms/step
